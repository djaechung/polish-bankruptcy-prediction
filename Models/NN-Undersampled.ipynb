# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats.mstats import winsorize

# %%
train_imputed= pd.read_csv("train_undersampled_imputed.csv")

test_imputed= pd.read_csv("test_imputed.csv")

# %%
train_imputed
# Out:
#         Attr1     Attr2     Attr3     Attr4    Attr5    Attr6     Attr7  \
# 0    0.079231  0.415260  0.202670   1.78000  176.540  0.00000  0.100140
# 1    0.003415  1.303300  0.218210   2.35380   -4.257 -0.25107  0.003985
# 2    0.047082  0.563670  0.191850   2.14420  -20.019  0.32158  0.055883
# 3    0.040089  0.772660  0.117240   1.15200  -26.314  0.00000  0.040089
# 4    0.013250  0.116540  0.697820   6.98790  102.770  0.21668  0.021259
# ..        ...       ...       ...       ...      ...      ...       ...
# 737  0.005271  0.502380 -0.259600   0.30124 -197.040 -0.41014  0.005271
# 738  0.074195  0.672300 -0.031192   0.86366  -17.329  0.00000  0.090630
# 739  0.218920  0.778210 -0.136800   0.81142  -97.247 -0.96821  0.218920
# 740  0.034309  0.049201  0.455710  10.26200   30.232  0.00000  0.034309
# 741 -0.160120  0.551710 -0.048174   0.86931 -135.090  0.00000 -0.160120
#
#         Attr8    Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# 0     1.40810  3.77470  0.58474  ...  0.153900  0.135500  0.86153  0.065178
# 1    -0.24681  1.06210 -0.32167  ...  0.058428 -0.010615  0.94157 -3.550600
# 2     0.77408  1.01090  0.43633  ...  0.045711  0.107900  0.90674  0.907580
# 3     0.29422  0.91757  0.22734  ...  0.094252  0.176340  0.95632  0.000000
# 4     7.28580  1.01450  0.84907  ...  0.014297  0.015605  0.98570  0.000000
# ..        ...      ...      ...  ...       ...       ...      ...       ...
# 737   0.99053  0.65435  0.49762  ...  0.067636  0.010593  0.94242  0.240360
# 738   0.48725  2.27440  0.32758  ...  0.046334  0.226500  0.95361  1.353900
# 739   0.28500  1.95560  0.22179  ...  0.060739  0.987060  0.88226  0.238120
# 740  19.32500  4.22970  0.95080  ...  0.003818  0.036085  0.99658  0.000000
# 741   0.81256  0.62292  0.44829  ...  0.111290 -0.357170  1.25350  0.324470
#
#       Attr60   Attr61    Attr62   Attr63    Attr64  class
# 0    28.1410  13.3570   25.1250  14.5270   7.02270      0
# 1     5.1968  14.1030   49.0650   7.4391   1.93200      0
# 2     4.3870   8.8181   60.5380   6.0292   1.57840      0
# 3     5.2162   1.2946  306.7700   1.1898   8.22340      0
# 4    15.6360   4.2304   20.9860  17.3920  10.91800      0
# ..       ...      ...       ...      ...       ...    ...
# 737  35.8000   7.3203  207.2300   1.7613   0.73687      1
# 738  32.5290  17.9960   36.7150   9.9413   2.83490      1
# 739   5.5662   8.4464  135.3900   2.6960   4.75370      1
# 740  40.7590  14.5600    4.2458  85.9680   8.54330      1
# 741   2.6813   8.0631  215.9800   1.6900   0.91663      1
#
# [742 rows x 65 columns]

# %%
y_train_imputed = train_imputed.iloc[:,64]
x_train_imputed = train_imputed.drop('class', inplace=True, axis=1)
x_train_imputed = train_imputed.copy()

y_test_imputed = test_imputed.iloc[:,64]
x_test_imputed = test_imputed.drop('class', inplace=True, axis=1)
x_test_imputed = test_imputed.copy()

# %%
train_imputed
# Out:
#         Attr1     Attr2     Attr3     Attr4    Attr5    Attr6     Attr7  \
# 0    0.079231  0.415260  0.202670   1.78000  176.540  0.00000  0.100140
# 1    0.003415  1.303300  0.218210   2.35380   -4.257 -0.25107  0.003985
# 2    0.047082  0.563670  0.191850   2.14420  -20.019  0.32158  0.055883
# 3    0.040089  0.772660  0.117240   1.15200  -26.314  0.00000  0.040089
# 4    0.013250  0.116540  0.697820   6.98790  102.770  0.21668  0.021259
# ..        ...       ...       ...       ...      ...      ...       ...
# 737  0.005271  0.502380 -0.259600   0.30124 -197.040 -0.41014  0.005271
# 738  0.074195  0.672300 -0.031192   0.86366  -17.329  0.00000  0.090630
# 739  0.218920  0.778210 -0.136800   0.81142  -97.247 -0.96821  0.218920
# 740  0.034309  0.049201  0.455710  10.26200   30.232  0.00000  0.034309
# 741 -0.160120  0.551710 -0.048174   0.86931 -135.090  0.00000 -0.160120
#
#         Attr8    Attr9   Attr10  ...      Attr55    Attr56    Attr57   Attr58  \
# 0     1.40810  3.77470  0.58474  ...  31625.0000  0.153900  0.135500  0.86153
# 1    -0.24681  1.06210 -0.32167  ...   4945.1000  0.058428 -0.010615  0.94157
# 2     0.77408  1.01090  0.43633  ...      2.1442  0.045711  0.107900  0.90674
# 3     0.29422  0.91757  0.22734  ...   1308.5000  0.094252  0.176340  0.95632
# 4     7.28580  1.01450  0.84907  ...   8104.3000  0.014297  0.015605  0.98570
# ..        ...      ...      ...  ...         ...       ...       ...      ...
# 737   0.99053  0.65435  0.49762  ...  -3273.0000  0.067636  0.010593  0.94242
# 738   0.48725  2.27440  0.32758  ...   -251.0000  0.046334  0.226500  0.95361
# 739   0.28500  1.95560  0.22179  ...    -71.0000  0.060739  0.987060  0.88226
# 740  19.32500  4.22970  0.95080  ...    510.5800  0.003818  0.036085  0.99658
# 741   0.81256  0.62292  0.44829  ...   -524.3800  0.111290 -0.357170  1.25350
#
#        Attr59   Attr60   Attr61    Attr62   Attr63    Attr64
# 0    0.065178  28.1410  13.3570   25.1250  14.5270   7.02270
# 1   -3.550600   5.1968  14.1030   49.0650   7.4391   1.93200
# 2    0.907580   4.3870   8.8181   60.5380   6.0292   1.57840
# 3    0.000000   5.2162   1.2946  306.7700   1.1898   8.22340
# 4    0.000000  15.6360   4.2304   20.9860  17.3920  10.91800
# ..        ...      ...      ...       ...      ...       ...
# 737  0.240360  35.8000   7.3203  207.2300   1.7613   0.73687
# 738  1.353900  32.5290  17.9960   36.7150   9.9413   2.83490
# 739  0.238120   5.5662   8.4464  135.3900   2.6960   4.75370
# 740  0.000000  40.7590  14.5600    4.2458  85.9680   8.54330
# 741  0.324470   2.6813   8.0631  215.9800   1.6900   0.91663
#
# [742 rows x 64 columns]

# %%
train_imputed.describe()
x_test_imputed.describe()
# Out:
#              Attr1        Attr2        Attr3        Attr4         Attr5  \
# count  2626.000000  2626.000000  2626.000000  2626.000000  2.626000e+03
# mean      0.048154     0.528513     0.184111     4.381265 -8.336369e+02
# std       0.222433     0.505946     0.445156    30.992906  4.190096e+04
# min      -2.255800     0.000000    -9.056700     0.024246 -1.670200e+06
# 25%       0.001053     0.251567     0.020252     1.054575 -5.224100e+01
# 50%       0.041483     0.464415     0.197700     1.596350  2.216400e+00
# 75%       0.124353     0.691063     0.420140     3.004975  5.601975e+01
# max       2.857200    10.057000     1.000000   991.190000  6.854400e+05
#
#               Attr6        Attr7         Attr8        Attr9       Attr10  ...  \
# count  2.626000e+03  2626.000000   2626.000000  2626.000000  2626.000000  ...
# mean  -3.967021e-02     0.061137     16.007281     1.748573     0.454546  ...
# std    1.138120e+00     0.230724    579.283618     2.013620     0.505176  ...
# min   -4.301900e+01    -2.255800     -0.900560     0.000000    -9.056700  ...
# 25%    6.938894e-18     0.002376      0.429228     1.009600     0.293605  ...
# 50%    6.938894e-18     0.049533      1.115100     1.186400     0.516015  ...
# 75%    8.321475e-02     0.142770      2.924950     2.035675     0.728563  ...
# max    1.711300e+01     2.991300  29636.000000    63.482000     1.000000  ...
#
#              Attr55       Attr56       Attr57       Attr58       Attr59  \
# count  2.626000e+03  2626.000000  2626.000000  2626.000000  2626.000000
# mean   6.093210e+03     0.041419    -0.357479     0.999420     4.115336
# std    6.205073e+04     0.956476    34.334833     5.980477   153.054504
# min   -7.513800e+05   -41.519000 -1667.300000  -198.690000  -136.290000
# 25%    2.346825e+01     0.005021     0.008733     0.876530     0.000000
# 50%    8.684400e+02     0.051367     0.104725     0.953315     0.001451
# 75%    4.208150e+03     0.127208     0.280810     0.996865     0.239490
# max    2.653200e+06     1.820100   527.220000   167.400000  7617.300000
#
#               Attr60       Attr61        Attr62       Attr63        Attr64
# count    2626.000000  2626.000000   2626.000000  2626.000000   2626.000000
# mean      224.813769    14.667281    122.650050     8.818548     52.738475
# std      4629.704090    99.646080    415.149782    20.021674    638.857982
# min         0.000000    -2.890697      0.000000     0.000000    -10.624955
# 25%         5.783800     4.618575     39.784250     3.105400      2.035675
# 50%        10.730500     6.787250     68.849500     5.299450      4.146700
# 75%        25.602500    10.806500    117.615000     9.165575     10.071000
# max    203500.000000  4470.400000  16701.000000   663.030000  21499.000000
#
# [8 rows x 64 columns]

# %%
for i in range(0,64):
        winsorize(x_train_imputed.iloc[:,0], limits=[0.1, 0.1])
        winsorize(x_test_imputed.iloc[:,0], limits=[0.1, 0.1])
        
x_train_imputed.describe()
x_test_imputed.describe()
# Out:
#              Attr1        Attr2        Attr3        Attr4         Attr5  \
# count  2626.000000  2626.000000  2626.000000  2626.000000  2.626000e+03
# mean      0.048154     0.528513     0.184111     4.381265 -8.336369e+02
# std       0.222433     0.505946     0.445156    30.992906  4.190096e+04
# min      -2.255800     0.000000    -9.056700     0.024246 -1.670200e+06
# 25%       0.001053     0.251567     0.020252     1.054575 -5.224100e+01
# 50%       0.041483     0.464415     0.197700     1.596350  2.216400e+00
# 75%       0.124353     0.691063     0.420140     3.004975  5.601975e+01
# max       2.857200    10.057000     1.000000   991.190000  6.854400e+05
#
#               Attr6        Attr7         Attr8        Attr9       Attr10  ...  \
# count  2.626000e+03  2626.000000   2626.000000  2626.000000  2626.000000  ...
# mean  -3.967021e-02     0.061137     16.007281     1.748573     0.454546  ...
# std    1.138120e+00     0.230724    579.283618     2.013620     0.505176  ...
# min   -4.301900e+01    -2.255800     -0.900560     0.000000    -9.056700  ...
# 25%    6.938894e-18     0.002376      0.429228     1.009600     0.293605  ...
# 50%    6.938894e-18     0.049533      1.115100     1.186400     0.516015  ...
# 75%    8.321475e-02     0.142770      2.924950     2.035675     0.728563  ...
# max    1.711300e+01     2.991300  29636.000000    63.482000     1.000000  ...
#
#              Attr55       Attr56       Attr57       Attr58       Attr59  \
# count  2.626000e+03  2626.000000  2626.000000  2626.000000  2626.000000
# mean   6.093210e+03     0.041419    -0.357479     0.999420     4.115336
# std    6.205073e+04     0.956476    34.334833     5.980477   153.054504
# min   -7.513800e+05   -41.519000 -1667.300000  -198.690000  -136.290000
# 25%    2.346825e+01     0.005021     0.008733     0.876530     0.000000
# 50%    8.684400e+02     0.051367     0.104725     0.953315     0.001451
# 75%    4.208150e+03     0.127208     0.280810     0.996865     0.239490
# max    2.653200e+06     1.820100   527.220000   167.400000  7617.300000
#
#               Attr60       Attr61        Attr62       Attr63        Attr64
# count    2626.000000  2626.000000   2626.000000  2626.000000   2626.000000
# mean      224.813769    14.667281    122.650050     8.818548     52.738475
# std      4629.704090    99.646080    415.149782    20.021674    638.857982
# min         0.000000    -2.890697      0.000000     0.000000    -10.624955
# 25%         5.783800     4.618575     39.784250     3.105400      2.035675
# 50%        10.730500     6.787250     68.849500     5.299450      4.146700
# 75%        25.602500    10.806500    117.615000     9.165575     10.071000
# max    203500.000000  4470.400000  16701.000000   663.030000  21499.000000
#
# [8 rows x 64 columns]

# %%
np.set_printoptions(precision = 3, suppress = True)
x_train_imputed.describe()
# Out:
#             Attr1       Attr2       Attr3       Attr4         Attr5  \
# count  742.000000  742.000000  742.000000  742.000000    742.000000
# mean    -0.020252    1.250269   -0.515865    6.367265    -62.125372
# std      1.095122   16.405980   16.392164   49.450230    729.312904
# min    -17.692000    0.000000 -445.880000    0.002238 -11723.000000
# 25%     -0.051195    0.317940   -0.049535    0.888450    -77.769500
# 50%      0.018909    0.559725    0.141040    1.335200    -15.201500
# 75%      0.089249    0.772132    0.355473    2.372325     33.820250
# max     20.481000  446.880000    0.998200  886.690000   8447.300000
#
#             Attr6       Attr7        Attr8       Attr9      Attr10  ...  \
# count  742.000000  742.000000   742.000000  742.000000  742.000000  ...
# mean    -0.848354   -0.010224     6.152784    1.954107   -0.274764  ...
# std     18.063961    1.097144    70.144027    6.419760   16.404857  ...
# min   -486.720000  -17.692000    -2.081800    0.000000 -445.860000  ...
# 25%     -0.047274   -0.046151     0.273420    0.979475    0.209617  ...
# 50%      0.000000    0.024066     0.742850    1.136250    0.414800  ...
# 75%      0.010388    0.111067     2.078300    2.086100    0.657048  ...
# max      0.910180   20.481000  1805.200000  169.500000    0.999450  ...
#
#              Attr55       Attr56      Attr57        Attr58      Attr59  \
# count  7.420000e+02   742.000000  742.000000    742.000000  742.000000
# mean   4.890057e+03    -2.127820   -0.497917     25.806549    0.422036
# std    5.335214e+04    58.050951   12.027906    665.171593    5.521869
# min   -4.203100e+05 -1581.184750 -267.450000      0.000000  -94.598000
# 25%   -2.205700e+02    -0.014866   -0.042885      0.878920    0.000000
# 50%    4.434800e+02     0.036939    0.078390      0.964195    0.000219
# 75%    2.729725e+03     0.120112    0.237320      1.017125    0.243310
# max    1.108900e+06     1.000000   57.541000  18118.000000  102.220000
#
#              Attr60       Attr61         Attr62       Attr63        Attr64
# count  7.420000e+02   742.000000     742.000000   742.000000  7.420000e+02
# mean   5.323721e+01    12.954177     929.851794    10.111678  2.938234e+01
# std    4.982691e+02    41.886674   15270.289660    54.952547  1.684059e+02
# min   -1.136868e-13     0.000000       0.000000     0.000000  3.552714e-15
# 25%    5.110800e+00     4.439125      46.086750     2.515750  1.930500e+00
# 50%    8.653500e+00     6.700150      83.775500     4.328000  3.937900e+00
# 75%    1.794130e+01    11.932750     143.695000     7.871975  9.769950e+00
# max    1.283000e+04  1060.600000  359250.000000  1266.200000  3.544600e+03
#
# [8 rows x 64 columns]

# %%
counts = np.bincount(y_train_imputed)
counts
# Out:
# array([371, 371])

# %%
weight_0 = 1/ counts[0]
weight_1 = 1/counts[1]

# %%
mean = np.mean(x_train_imputed,axis=0)
std = np.std(x_train_imputed,axis=0)

# %%
x_train_imputed = (x_train_imputed - mean) / std
x_test_imputed = (x_test_imputed - mean) / std

# %%
model = keras.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(x_train_imputed.shape[-1],)),
    keras.layers.Dense(16, activation=tf.nn.relu), keras.layers.Dropout(0.3),
    keras.layers.Dense(16, activation=tf.nn.relu), keras.layers.Dropout(0.3),
    keras.layers.Dense(1, activation=tf.nn.sigmoid),
])

model.summary()
# Out:
# Metal device set to: Apple M1 Pro
# 2022-12-03 09:55:44.687146: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-12-03 09:55:44.687300: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                1040
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_2 (Dense)             (None, 16)                272
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,601
# Trainable params: 1,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
metrics = [keras.metrics.FalseNegatives(name="fn"),
           keras.metrics.FalsePositives(name="fp"),
           keras.metrics.Precision(name="precision"),
           keras.metrics.Recall(name="recall"),
           keras.metrics.AUC(name="auc")]

# %%
model.compile(optimizer= keras.optimizers.Adam(1e-2),
              loss="binary_crossentropy", metrics= metrics)

# %%
class_weights = {0:weight_0,1:weight_1}

# %%
def learningcurve(history):
  # list all data in history
  print(history.history.keys())
  # summarize history for AUC
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model auc')
  plt.ylabel('auc')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for precision
  plt.plot(history.history['precision'])
  plt.plot(history.history['val_precision'])
  plt.title('model precision')
  plt.ylabel('precision')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for recall
  plt.plot(history.history['recall'])
  plt.plot(history.history['val_recall'])
  plt.title('model recall')
  plt.ylabel('recall')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %%
history = model.fit(x_train_imputed, y_train_imputed, batch_size = 1024,
                     epochs=30, verbose=2,
                     validation_data = (x_test_imputed, y_test_imputed),class_weight=class_weights)
#learningcurve(history)
# Out:
# Epoch 1/30
# 2022-12-03 09:56:00.452238: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-12-03 09:56:00.910330: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-03 09:56:03.567605: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 - 3s - loss: 0.0020 - fn: 165.0000 - fp: 235.0000 - precision: 0.4671 - recall: 0.5553 - auc: 0.4478 - val_loss: 2.7398 - val_fn: 77.0000 - val_fp: 981.0000 - val_precision: 0.0457 - val_recall: 0.3790 - val_auc: 0.5010 - 3s/epoch - 3s/step
# Epoch 2/30
# 1/1 - 0s - loss: 0.0019 - fn: 207.0000 - fp: 185.0000 - precision: 0.4699 - recall: 0.4420 - auc: 0.4730 - val_loss: 2.5202 - val_fn: 103.0000 - val_fp: 341.0000 - val_precision: 0.0580 - val_recall: 0.1694 - val_auc: 0.5440 - 49ms/epoch - 49ms/step
# Epoch 3/30
# 1/1 - 0s - loss: 0.0019 - fn: 261.0000 - fp: 111.0000 - precision: 0.4977 - recall: 0.2965 - auc: 0.5124 - val_loss: 2.3754 - val_fn: 106.0000 - val_fp: 232.0000 - val_precision: 0.0720 - val_recall: 0.1452 - val_auc: 0.5874 - 46ms/epoch - 46ms/step
# Epoch 4/30
# 1/1 - 0s - loss: 0.0019 - fn: 274.0000 - fp: 86.0000 - precision: 0.5301 - recall: 0.2615 - auc: 0.5211 - val_loss: 2.3541 - val_fn: 100.0000 - val_fp: 266.0000 - val_precision: 0.0828 - val_recall: 0.1935 - val_auc: 0.6033 - 45ms/epoch - 45ms/step
# Epoch 5/30
# 1/1 - 0s - loss: 0.0019 - fn: 273.0000 - fp: 85.0000 - precision: 0.5355 - recall: 0.2642 - auc: 0.5598 - val_loss: 2.3357 - val_fn: 94.0000 - val_fp: 333.0000 - val_precision: 0.0826 - val_recall: 0.2419 - val_auc: 0.6175 - 46ms/epoch - 46ms/step
# Epoch 6/30
# 1/1 - 0s - loss: 0.0018 - fn: 256.0000 - fp: 86.0000 - precision: 0.5721 - recall: 0.3100 - auc: 0.5852 - val_loss: 2.2987 - val_fn: 87.0000 - val_fp: 399.0000 - val_precision: 0.0849 - val_recall: 0.2984 - val_auc: 0.6259 - 47ms/epoch - 47ms/step
# Epoch 7/30
# 1/1 - 0s - loss: 0.0018 - fn: 219.0000 - fp: 85.0000 - precision: 0.6414 - recall: 0.4097 - auc: 0.6410 - val_loss: 2.2816 - val_fn: 78.0000 - val_fp: 542.0000 - val_precision: 0.0782 - val_recall: 0.3710 - val_auc: 0.6295 - 47ms/epoch - 47ms/step
# Epoch 8/30
# 1/1 - 0s - loss: 0.0018 - fn: 204.0000 - fp: 105.0000 - precision: 0.6140 - recall: 0.4501 - auc: 0.6258 - val_loss: 2.3041 - val_fn: 72.0000 - val_fp: 690.0000 - val_precision: 0.0701 - val_recall: 0.4194 - val_auc: 0.6352 - 47ms/epoch - 47ms/step
# Epoch 9/30
# 1/1 - 0s - loss: 0.0018 - fn: 184.0000 - fp: 118.0000 - precision: 0.6131 - recall: 0.5040 - auc: 0.6446 - val_loss: 2.3272 - val_fn: 69.0000 - val_fp: 725.0000 - val_precision: 0.0705 - val_recall: 0.4435 - val_auc: 0.6378 - 49ms/epoch - 49ms/step
# Epoch 10/30
# 1/1 - 0s - loss: 0.0018 - fn: 178.0000 - fp: 116.0000 - precision: 0.6246 - recall: 0.5202 - auc: 0.6500 - val_loss: 2.3703 - val_fn: 66.0000 - val_fp: 724.0000 - val_precision: 0.0742 - val_recall: 0.4677 - val_auc: 0.6448 - 51ms/epoch - 51ms/step
# Epoch 11/30
# 1/1 - 0s - loss: 0.0018 - fn: 166.0000 - fp: 110.0000 - precision: 0.6508 - recall: 0.5526 - auc: 0.6741 - val_loss: 2.4237 - val_fn: 63.0000 - val_fp: 751.0000 - val_precision: 0.0751 - val_recall: 0.4919 - val_auc: 0.6516 - 49ms/epoch - 49ms/step
# Epoch 12/30
# 1/1 - 0s - loss: 0.0018 - fn: 165.0000 - fp: 116.0000 - precision: 0.6398 - recall: 0.5553 - auc: 0.6811 - val_loss: 2.5412 - val_fn: 62.0000 - val_fp: 794.0000 - val_precision: 0.0724 - val_recall: 0.5000 - val_auc: 0.6573 - 49ms/epoch - 49ms/step
# Epoch 13/30
# 1/1 - 0s - loss: 0.0018 - fn: 144.0000 - fp: 126.0000 - precision: 0.6431 - recall: 0.6119 - auc: 0.6841 - val_loss: 2.6500 - val_fn: 57.0000 - val_fp: 814.0000 - val_precision: 0.0760 - val_recall: 0.5403 - val_auc: 0.6635 - 46ms/epoch - 46ms/step
# Epoch 14/30
# 1/1 - 0s - loss: 0.0018 - fn: 152.0000 - fp: 135.0000 - precision: 0.6186 - recall: 0.5903 - auc: 0.6600 - val_loss: 2.7660 - val_fn: 53.0000 - val_fp: 868.0000 - val_precision: 0.0756 - val_recall: 0.5726 - val_auc: 0.6678 - 46ms/epoch - 46ms/step
# Epoch 15/30
# 1/1 - 0s - loss: 0.0017 - fn: 135.0000 - fp: 145.0000 - precision: 0.6194 - recall: 0.6361 - auc: 0.6910 - val_loss: 2.8889 - val_fn: 48.0000 - val_fp: 921.0000 - val_precision: 0.0762 - val_recall: 0.6129 - val_auc: 0.6702 - 46ms/epoch - 46ms/step
# Epoch 16/30
# 1/1 - 0s - loss: 0.0017 - fn: 117.0000 - fp: 145.0000 - precision: 0.6366 - recall: 0.6846 - auc: 0.7052 - val_loss: 3.0345 - val_fn: 44.0000 - val_fp: 954.0000 - val_precision: 0.0774 - val_recall: 0.6452 - val_auc: 0.6746 - 44ms/epoch - 44ms/step
# Epoch 17/30
# 1/1 - 0s - loss: 0.0017 - fn: 113.0000 - fp: 148.0000 - precision: 0.6355 - recall: 0.6954 - auc: 0.7037 - val_loss: 3.2177 - val_fn: 35.0000 - val_fp: 1025.0000 - val_precision: 0.0799 - val_recall: 0.7177 - val_auc: 0.6750 - 46ms/epoch - 46ms/step
# Epoch 18/30
# 1/1 - 0s - loss: 0.0017 - fn: 97.0000 - fp: 154.0000 - precision: 0.6402 - recall: 0.7385 - auc: 0.7112 - val_loss: 3.4088 - val_fn: 33.0000 - val_fp: 1087.0000 - val_precision: 0.0772 - val_recall: 0.7339 - val_auc: 0.6769 - 45ms/epoch - 45ms/step
# Epoch 19/30
# 1/1 - 0s - loss: 0.0017 - fn: 98.0000 - fp: 159.0000 - precision: 0.6319 - recall: 0.7358 - auc: 0.7077 - val_loss: 3.6113 - val_fn: 33.0000 - val_fp: 1128.0000 - val_precision: 0.0747 - val_recall: 0.7339 - val_auc: 0.6782 - 49ms/epoch - 49ms/step
# Epoch 20/30
# 1/1 - 0s - loss: 0.0017 - fn: 82.0000 - fp: 160.0000 - precision: 0.6437 - recall: 0.7790 - auc: 0.7184 - val_loss: 3.8316 - val_fn: 32.0000 - val_fp: 1117.0000 - val_precision: 0.0761 - val_recall: 0.7419 - val_auc: 0.6813 - 50ms/epoch - 50ms/step
# Epoch 21/30
# 1/1 - 0s - loss: 0.0017 - fn: 87.0000 - fp: 157.0000 - precision: 0.6440 - recall: 0.7655 - auc: 0.7311 - val_loss: 4.0711 - val_fn: 33.0000 - val_fp: 1113.0000 - val_precision: 0.0756 - val_recall: 0.7339 - val_auc: 0.6833 - 51ms/epoch - 51ms/step
# Epoch 22/30
# 1/1 - 0s - loss: 0.0016 - fn: 74.0000 - fp: 162.0000 - precision: 0.6471 - recall: 0.8005 - auc: 0.7485 - val_loss: 4.3328 - val_fn: 33.0000 - val_fp: 1074.0000 - val_precision: 0.0781 - val_recall: 0.7339 - val_auc: 0.6867 - 51ms/epoch - 51ms/step
# Epoch 23/30
# 1/1 - 0s - loss: 0.0016 - fn: 80.0000 - fp: 150.0000 - precision: 0.6599 - recall: 0.7844 - auc: 0.7265 - val_loss: 4.6250 - val_fn: 35.0000 - val_fp: 1028.0000 - val_precision: 0.0797 - val_recall: 0.7177 - val_auc: 0.6895 - 47ms/epoch - 47ms/step
# Epoch 24/30
# 1/1 - 0s - loss: 0.0016 - fn: 94.0000 - fp: 145.0000 - precision: 0.6564 - recall: 0.7466 - auc: 0.7320 - val_loss: 4.9407 - val_fn: 32.0000 - val_fp: 1057.0000 - val_precision: 0.0801 - val_recall: 0.7419 - val_auc: 0.6923 - 46ms/epoch - 46ms/step
# Epoch 25/30
# 1/1 - 0s - loss: 0.0016 - fn: 84.0000 - fp: 150.0000 - precision: 0.6568 - recall: 0.7736 - auc: 0.7453 - val_loss: 5.1846 - val_fn: 30.0000 - val_fp: 1093.0000 - val_precision: 0.0792 - val_recall: 0.7581 - val_auc: 0.6945 - 46ms/epoch - 46ms/step
# Epoch 26/30
# 1/1 - 0s - loss: 0.0016 - fn: 85.0000 - fp: 142.0000 - precision: 0.6682 - recall: 0.7709 - auc: 0.7648 - val_loss: 5.4179 - val_fn: 28.0000 - val_fp: 1163.0000 - val_precision: 0.0763 - val_recall: 0.7742 - val_auc: 0.6961 - 46ms/epoch - 46ms/step
# Epoch 27/30
# 1/1 - 0s - loss: 0.0016 - fn: 75.0000 - fp: 159.0000 - precision: 0.6505 - recall: 0.7978 - auc: 0.7512 - val_loss: 5.5856 - val_fn: 26.0000 - val_fp: 1190.0000 - val_precision: 0.0761 - val_recall: 0.7903 - val_auc: 0.6974 - 45ms/epoch - 45ms/step
# Epoch 28/30
# 1/1 - 0s - loss: 0.0016 - fn: 65.0000 - fp: 155.0000 - precision: 0.6638 - recall: 0.8248 - auc: 0.7725 - val_loss: 5.6631 - val_fn: 27.0000 - val_fp: 1150.0000 - val_precision: 0.0778 - val_recall: 0.7823 - val_auc: 0.6994 - 44ms/epoch - 44ms/step
# Epoch 29/30
# 1/1 - 0s - loss: 0.0016 - fn: 72.0000 - fp: 143.0000 - precision: 0.6765 - recall: 0.8059 - auc: 0.7666 - val_loss: 5.7200 - val_fn: 29.0000 - val_fp: 1094.0000 - val_precision: 0.0799 - val_recall: 0.7661 - val_auc: 0.7016 - 45ms/epoch - 45ms/step
# Epoch 30/30
# 1/1 - 0s - loss: 0.0016 - fn: 80.0000 - fp: 148.0000 - precision: 0.6629 - recall: 0.7844 - auc: 0.7586 - val_loss: 5.7849 - val_fn: 30.0000 - val_fp: 1035.0000 - val_precision: 0.0833 - val_recall: 0.7581 - val_auc: 0.7018 - 44ms/epoch - 44ms/step

# %%
from keras.callbacks import TensorBoard
from tensorboard.plugins.pr_curve import summary as pr_summary

# Check complete example in:
# https://github.com/akionakamura/pr-tensorboard-keras-example
class PRTensorBoard(TensorBoard):
    def __init__(self, *args, **kwargs):
        # One extra argument to indicate whether or not to use the PR curve summary.
        self.pr_curve = kwargs.pop('pr_curve', True)
        super(PRTensorBoard, self).__init__(*args, **kwargs)

        global tf
        import tensorflow as tf

    def set_model(self, model):
        super(PRTensorBoard, self).set_model(model)

        if self.pr_curve:
            # Get the prediction and label tensor placeholders.
            predictions = self.model._feed_outputs[0]
            labels = tf.cast(self.model._feed_targets[0], tf.bool)
            # Create the PR summary OP.
            self.pr_summary = pr_summary.op(tag='pr_curve',
                                            predictions=predictions,
                                            labels=labels,
                                            display_name='Precision-Recall Curve')

    def on_epoch_end(self, epoch, logs=None):
        super(PRTensorBoard, self).on_epoch_end(epoch, logs)

        if self.pr_curve and self.validation_data:
            # Get the tensors again.
            tensors = self.model._feed_targets + self.model._feed_outputs
            # Predict the output.
            predictions = self.model.predict(self.validation_data[:-2])
            # Build the dictionary mapping the tensor to the data.
            val_data = [self.validation_data[-2], predictions]
            feed_dict = dict(zip(tensors, val_data))
            # Run and add summary.
            result = self.sess.run([self.pr_summary], feed_dict=feed_dict)
            self.writer.add_summary(result[0], epoch)
        self.writer.flush()
