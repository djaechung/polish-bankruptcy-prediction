# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats.mstats import winsorize

# %%
train_imputed= pd.read_csv("train_imputed.csv")
train_undersampled_imputed= pd.read_csv("train_undersampled_imputed.csv")
train_oversampled_imputed= pd.read_csv("train_oversampled_imputed.csv")

test_imputed= pd.read_csv("test_imputed.csv")

# %%
train_imputed
# Out:
#          Attr1     Attr2     Attr3    Attr4     Attr5     Attr6     Attr7  \
# 0     0.003235  0.282480  0.591250  3.09310    56.934  0.000000  0.006650
# 1     0.138540  0.590490  0.188250  2.72950    39.749  0.000000  0.175000
# 2     0.030908  0.561760  0.132070  1.29780   -12.138  0.025807  0.039266
# 3    -0.122580  0.589900 -0.244460  0.58373  -271.440 -0.223030 -0.122580
# 4     0.364080  0.288920  0.732720  4.19170    74.581  0.164770  0.450600
# ...        ...       ...       ...      ...       ...       ...       ...
# 7872  0.057635  0.065294  0.474420  8.26590   223.780  0.561330  0.057635
# 7873  0.067541  0.792770 -0.095114  0.85299   -41.693  0.000000  0.067541
# 7874  0.034557  0.249570  0.390950  2.86350  1524.100  0.000000  0.034557
# 7875 -0.157370  0.715300 -0.135370  0.71957   -77.885 -0.386440 -0.157370
# 7876  0.327200  0.717630 -0.037330  0.94798   -23.762  0.000000  0.327200
#
#          Attr8    Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# 0      2.54010  2.08750  0.71752  ...  0.001677  0.004509  0.99682  0.000000
# 1      0.69352  1.33530  0.40951  ...  0.135000  0.338300  0.86895  1.176100
# 2      0.75046  1.06480  0.42158  ...  0.060845  0.073315  0.93915  0.280560
# 3      0.69521  0.56201  0.41010  ... -0.118240 -0.298910  1.21520  0.000000
# 4      2.46120  2.85430  0.71108  ...  0.163920  0.512010  0.84217  0.000000
# ...        ...      ...      ...  ...       ...       ...      ...       ...
# 7872  14.31500  1.08030  0.93471  ...  0.074365  0.061661  0.92563  0.000000
# 7873   0.26139  2.41510  0.20723  ...  0.030497  0.325930  0.97250  0.695480
# 7874   3.00690  0.32045  0.75043  ...  0.557800  0.046049  0.62503  0.038976
# 7875   0.39802  2.20150  0.28470  ...  0.080866 -0.552760  0.92122  0.748290
# 7876   0.39347  2.61710  0.28237  ...  0.123150  1.158800  0.87696  0.000000
#
#        Attr60   Attr61   Attr62    Attr63    Attr64  class
# 0      8.0157   6.1864   49.392   7.38980  16.53100      0
# 1     21.3360  28.8410   29.753  12.26800   1.89960      0
# 2     10.8990   5.9638   83.020   4.39650   4.59370      0
# 3      2.8835   5.6354  381.410   0.95697   0.85518      0
# 4     18.4870  14.6300   29.357  12.43300  75.68700      0
# ...       ...      ...      ...       ...       ...    ...
# 7872   7.0557   1.9703   34.237  10.66100   1.51230      0
# 7873  16.6980   6.3733   97.779   3.73290   5.38900      0
# 7874   2.6820   1.3341  238.960   1.52740   0.80264      0
# 7875   7.9774  35.2250   80.030   4.56080   3.37320      0
# 7876  24.3060   4.6621  100.090   3.64680   8.18610      0
#
# [7877 rows x 65 columns]

# %%
y_train_imputed = train_imputed.iloc[:,64]
x_train_imputed = train_imputed.drop('class', inplace=True, axis=1)
x_train_imputed = train_imputed.copy()

y_test_imputed = test_imputed.iloc[:,64]
x_test_imputed = test_imputed.drop('class', inplace=True, axis=1)
x_test_imputed = test_imputed.copy()

# %%
train_imputed
# Out:
#          Attr1     Attr2     Attr3    Attr4     Attr5     Attr6     Attr7  \
# 0     0.003235  0.282480  0.591250  3.09310    56.934  0.000000  0.006650
# 1     0.138540  0.590490  0.188250  2.72950    39.749  0.000000  0.175000
# 2     0.030908  0.561760  0.132070  1.29780   -12.138  0.025807  0.039266
# 3    -0.122580  0.589900 -0.244460  0.58373  -271.440 -0.223030 -0.122580
# 4     0.364080  0.288920  0.732720  4.19170    74.581  0.164770  0.450600
# ...        ...       ...       ...      ...       ...       ...       ...
# 7872  0.057635  0.065294  0.474420  8.26590   223.780  0.561330  0.057635
# 7873  0.067541  0.792770 -0.095114  0.85299   -41.693  0.000000  0.067541
# 7874  0.034557  0.249570  0.390950  2.86350  1524.100  0.000000  0.034557
# 7875 -0.157370  0.715300 -0.135370  0.71957   -77.885 -0.386440 -0.157370
# 7876  0.327200  0.717630 -0.037330  0.94798   -23.762  0.000000  0.327200
#
#          Attr8    Attr9   Attr10  ...    Attr55    Attr56    Attr57   Attr58  \
# 0      2.54010  2.08750  0.71752  ...   2918.60  0.001677  0.004509  0.99682
# 1      0.69352  1.33530  0.40951  ...   1598.50  0.135000  0.338300  0.86895
# 2      0.75046  1.06480  0.42158  ...   1936.10  0.060845  0.073315  0.93915
# 3      0.69521  0.56201  0.41010  ...  -2523.20 -0.118240 -0.298910  1.21520
# 4      2.46120  2.85430  0.71108  ...   2535.80  0.163920  0.512010  0.84217
# ...        ...      ...      ...  ...       ...       ...       ...      ...
# 7872  14.31500  1.08030  0.93471  ...  38451.00  0.074365  0.061661  0.92563
# 7873   0.26139  2.41510  0.20723  ...   -964.15  0.030497  0.325930  0.97250
# 7874   3.00690  0.32045  0.75043  ...  49667.00  0.557800  0.046049  0.62503
# 7875   0.39802  2.20150  0.28470  ...   -907.43  0.080866 -0.552760  0.92122
# 7876   0.39347  2.61710  0.28237  ...   -190.02  0.123150  1.158800  0.87696
#
#         Attr59   Attr60   Attr61   Attr62    Attr63    Attr64
# 0     0.000000   8.0157   6.1864   49.392   7.38980  16.53100
# 1     1.176100  21.3360  28.8410   29.753  12.26800   1.89960
# 2     0.280560  10.8990   5.9638   83.020   4.39650   4.59370
# 3     0.000000   2.8835   5.6354  381.410   0.95697   0.85518
# 4     0.000000  18.4870  14.6300   29.357  12.43300  75.68700
# ...        ...      ...      ...      ...       ...       ...
# 7872  0.000000   7.0557   1.9703   34.237  10.66100   1.51230
# 7873  0.695480  16.6980   6.3733   97.779   3.73290   5.38900
# 7874  0.038976   2.6820   1.3341  238.960   1.52740   0.80264
# 7875  0.748290   7.9774  35.2250   80.030   4.56080   3.37320
# 7876  0.000000  24.3060   4.6621  100.090   3.64680   8.18610
#
# [7877 rows x 64 columns]

# %%
train_imputed.describe()
x_test_imputed.describe()
# Out:
#              Attr1        Attr2        Attr3        Attr4         Attr5  \
# count  2626.000000  2626.000000  2626.000000  2626.000000  2.626000e+03
# mean      0.048154     0.528513     0.184111     4.381265 -8.336369e+02
# std       0.222433     0.505946     0.445156    30.992906  4.190096e+04
# min      -2.255800     0.000000    -9.056700     0.024246 -1.670200e+06
# 25%       0.001053     0.251567     0.020252     1.054575 -5.224100e+01
# 50%       0.041483     0.464415     0.197700     1.596350  2.216400e+00
# 75%       0.124353     0.691063     0.420140     3.004975  5.601975e+01
# max       2.857200    10.057000     1.000000   991.190000  6.854400e+05
#
#               Attr6        Attr7         Attr8        Attr9       Attr10  ...  \
# count  2.626000e+03  2626.000000   2626.000000  2626.000000  2626.000000  ...
# mean  -3.967021e-02     0.061137     16.007281     1.748573     0.454546  ...
# std    1.138120e+00     0.230724    579.283618     2.013620     0.505176  ...
# min   -4.301900e+01    -2.255800     -0.900560     0.000000    -9.056700  ...
# 25%    6.938894e-18     0.002376      0.429228     1.009600     0.293605  ...
# 50%    6.938894e-18     0.049533      1.115100     1.186400     0.516015  ...
# 75%    8.321475e-02     0.142770      2.924950     2.035675     0.728563  ...
# max    1.711300e+01     2.991300  29636.000000    63.482000     1.000000  ...
#
#              Attr55       Attr56       Attr57       Attr58       Attr59  \
# count  2.626000e+03  2626.000000  2626.000000  2626.000000  2626.000000
# mean   6.093210e+03     0.041419    -0.357479     0.999420     4.115336
# std    6.205073e+04     0.956476    34.334833     5.980477   153.054504
# min   -7.513800e+05   -41.519000 -1667.300000  -198.690000  -136.290000
# 25%    2.346825e+01     0.005021     0.008733     0.876530     0.000000
# 50%    8.684400e+02     0.051367     0.104725     0.953315     0.001451
# 75%    4.208150e+03     0.127208     0.280810     0.996865     0.239490
# max    2.653200e+06     1.820100   527.220000   167.400000  7617.300000
#
#               Attr60       Attr61        Attr62       Attr63        Attr64
# count    2626.000000  2626.000000   2626.000000  2626.000000   2626.000000
# mean      224.813769    14.667281    122.650050     8.818548     52.738475
# std      4629.704090    99.646080    415.149782    20.021674    638.857982
# min         0.000000    -2.890697      0.000000     0.000000    -10.624955
# 25%         5.783800     4.618575     39.784250     3.105400      2.035675
# 50%        10.730500     6.787250     68.849500     5.299450      4.146700
# 75%        25.602500    10.806500    117.615000     9.165575     10.071000
# max    203500.000000  4470.400000  16701.000000   663.030000  21499.000000
#
# [8 rows x 64 columns]

# %%
for i in range(0,64):
        winsorize(x_train_imputed.iloc[:,0], limits=[0.1, 0.1])
        winsorize(x_test_imputed.iloc[:,0], limits=[0.1, 0.1])
        
x_train_imputed.describe()
x_test_imputed.describe()
# Out:
#              Attr1        Attr2        Attr3        Attr4         Attr5  \
# count  2626.000000  2626.000000  2626.000000  2626.000000  2.626000e+03
# mean      0.048154     0.528513     0.184111     4.381265 -8.336369e+02
# std       0.222433     0.505946     0.445156    30.992906  4.190096e+04
# min      -2.255800     0.000000    -9.056700     0.024246 -1.670200e+06
# 25%       0.001053     0.251567     0.020252     1.054575 -5.224100e+01
# 50%       0.041483     0.464415     0.197700     1.596350  2.216400e+00
# 75%       0.124353     0.691063     0.420140     3.004975  5.601975e+01
# max       2.857200    10.057000     1.000000   991.190000  6.854400e+05
#
#               Attr6        Attr7         Attr8        Attr9       Attr10  ...  \
# count  2.626000e+03  2626.000000   2626.000000  2626.000000  2626.000000  ...
# mean  -3.967021e-02     0.061137     16.007281     1.748573     0.454546  ...
# std    1.138120e+00     0.230724    579.283618     2.013620     0.505176  ...
# min   -4.301900e+01    -2.255800     -0.900560     0.000000    -9.056700  ...
# 25%    6.938894e-18     0.002376      0.429228     1.009600     0.293605  ...
# 50%    6.938894e-18     0.049533      1.115100     1.186400     0.516015  ...
# 75%    8.321475e-02     0.142770      2.924950     2.035675     0.728563  ...
# max    1.711300e+01     2.991300  29636.000000    63.482000     1.000000  ...
#
#              Attr55       Attr56       Attr57       Attr58       Attr59  \
# count  2.626000e+03  2626.000000  2626.000000  2626.000000  2626.000000
# mean   6.093210e+03     0.041419    -0.357479     0.999420     4.115336
# std    6.205073e+04     0.956476    34.334833     5.980477   153.054504
# min   -7.513800e+05   -41.519000 -1667.300000  -198.690000  -136.290000
# 25%    2.346825e+01     0.005021     0.008733     0.876530     0.000000
# 50%    8.684400e+02     0.051367     0.104725     0.953315     0.001451
# 75%    4.208150e+03     0.127208     0.280810     0.996865     0.239490
# max    2.653200e+06     1.820100   527.220000   167.400000  7617.300000
#
#               Attr60       Attr61        Attr62       Attr63        Attr64
# count    2626.000000  2626.000000   2626.000000  2626.000000   2626.000000
# mean      224.813769    14.667281    122.650050     8.818548     52.738475
# std      4629.704090    99.646080    415.149782    20.021674    638.857982
# min         0.000000    -2.890697      0.000000     0.000000    -10.624955
# 25%         5.783800     4.618575     39.784250     3.105400      2.035675
# 50%        10.730500     6.787250     68.849500     5.299450      4.146700
# 75%        25.602500    10.806500    117.615000     9.165575     10.071000
# max    203500.000000  4470.400000  16701.000000   663.030000  21499.000000
#
# [8 rows x 64 columns]

# %%
np.set_printoptions(precision = 3, suppress = True)
x_train_imputed.describe()
# Out:
#              Attr1        Attr2        Attr3         Attr4         Attr5  \
# count  7877.000000  7877.000000  7877.000000   7877.000000  7.877000e+03
# mean      0.054408     0.650381     0.065946     11.851939 -1.513536e+03
# std       0.736924     7.415543     7.408786    603.932622  1.346097e+05
# min     -17.692000     0.000000  -479.730000      0.002080 -1.190300e+07
# 25%       0.000621     0.254530     0.016388      1.036400 -5.209900e+01
# 50%       0.043406     0.464140     0.198640      1.611000  1.360200e+00
# 75%       0.123800     0.689090     0.419450      2.944100  5.650500e+01
# max      52.652000   480.730000    17.708000  53433.000000  6.837700e+05
#
#              Attr6        Attr7         Attr8        Attr9       Attr10  ...  \
# count  7877.000000  7877.000000   7877.000000  7877.000000  7877.000000  ...
# mean     -0.148325     0.067120     20.205653     1.842384     0.336604  ...
# std       8.022194     0.740011    757.752041     8.675941     7.417382  ...
# min    -508.120000   -17.692000     -2.081800    -1.215700  -479.730000  ...
# 25%       0.000000     0.002050      0.432950     1.011800     0.297910  ...
# 50%       0.000000     0.051470      1.111600     1.201600     0.515500  ...
# 75%       0.068997     0.142080      2.846100     2.074600     0.724330  ...
# max      45.533000    52.652000  53432.000000   740.440000    11.837000  ...
#
#              Attr55       Attr56       Attr57        Attr58       Attr59  \
# count  7.877000e+03  7877.000000  7877.000000   7877.000000  7877.000000
# mean   6.820351e+03    -1.105573     0.099418      5.520766     0.533867
# std    5.915769e+04    68.880191     8.516169    225.303452    12.299323
# min   -6.699300e+05 -5691.700000  -267.450000     -1.328100  -172.070000
# 25%    1.170600e+01     0.005031     0.006263      0.875170     0.000000
# 50%    8.857300e+02     0.051807     0.107420      0.953020     0.003729
# 75%    4.402200e+03     0.130860     0.267510      0.995820     0.240520
# max    3.380500e+06   293.150000   552.640000  18118.000000   853.090000
#
#              Attr60       Attr61        Attr62       Attr63        Attr64
# count  7.877000e+03  7877.000000  7.877000e+03  7877.000000   7877.000000
# mean   8.897993e+02    13.676203  1.840772e+02     9.210065     31.477693
# std    4.407658e+04    77.574810  3.006323e+04    34.380370    323.082468
# min   -1.136868e-13    -6.590300 -2.336500e+06    -0.000156     -0.000102
# 25%    5.624900e+00     4.440100  4.123500e+01     3.049700      2.049700
# 50%    1.021300e+01     6.636200  7.164900e+01     5.076900      4.145300
# 75%    2.215000e+01    10.527000  1.191600e+02     8.804900     10.085000
# max    3.660200e+06  4246.700000  1.073500e+06  1974.500000  17902.000000
#
# [8 rows x 64 columns]

# %%
counts = np.bincount(y_train_imputed)
counts
# Out:
# array([7506,  371])

# %%
weight_0 = 1/ counts[0]
weight_1 = 1/counts[1]

# %%
mean = np.mean(x_train_imputed,axis=0)
std = np.std(x_train_imputed,axis=0)

# %%
x_train_imputed = (x_train_imputed - mean) / std
x_test_imputed = (x_test_imputed - mean) / std

# %%
model = keras.Sequential([
    keras.layers.Dense(64, activation=tf.nn.relu, input_shape=(x_train_imputed.shape[-1],)),
    keras.layers.Dense(64, activation=tf.nn.relu), keras.layers.Dropout(0.3),
    keras.layers.Dense(64, activation=tf.nn.relu), keras.layers.Dropout(0.3),
    keras.layers.Dense(1, activation=tf.nn.sigmoid),
])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 64)                4160
#
#  dense_21 (Dense)            (None, 64)                4160
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_22 (Dense)            (None, 64)                4160
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_23 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 12,545
# Trainable params: 12,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
metrics = [keras.metrics.FalseNegatives(name="fn"),
           keras.metrics.FalsePositives(name="fp"),
           keras.metrics.Precision(name="precision"),
           keras.metrics.Recall(name="recall"),
           keras.metrics.AUC(name="auc")]

# %%
model.compile(optimizer= keras.optimizers.Adam(1e-2),
              loss="binary_crossentropy", metrics= metrics)

# %%
class_weights = {0:weight_0,1:weight_1}

# %%
def learningcurve(history):
  # list all data in history
  print(history.history.keys())
  # summarize history for AUC
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model auc')
  plt.ylabel('auc')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for precision
  plt.plot(history.history['precision'])
  plt.plot(history.history['val_precision'])
  plt.title('model precision')
  plt.ylabel('precision')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for recall
  plt.plot(history.history['recall'])
  plt.plot(history.history['val_recall'])
  plt.title('model recall')
  plt.ylabel('recall')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %%
history = model.fit(x_train_imputed, y_train_imputed, batch_size = 1024,
                     epochs=30, verbose=2,
                     validation_data = (x_test_imputed, y_test_imputed),class_weight=class_weights)
#learningcurve(history)
# Out:
# Epoch 1/30
# 2022-12-03 09:54:08.568282: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 8/8 - 1s - loss: 1.7817e-04 - fn: 256.0000 - fp: 1793.0000 - precision: 0.0603 - recall: 0.3100 - auc: 0.5539 - val_loss: 0.7398 - val_fn: 25.0000 - val_fp: 1565.0000 - val_precision: 0.0595 - val_recall: 0.7984 - val_auc: 0.6493 - 1s/epoch - 130ms/step
# Epoch 2/30
# 2022-12-03 09:54:09.088008: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 8/8 - 0s - loss: 1.7297e-04 - fn: 75.0000 - fp: 4644.0000 - precision: 0.0599 - recall: 0.7978 - auc: 0.6587 - val_loss: 0.7068 - val_fn: 37.0000 - val_fp: 1039.0000 - val_precision: 0.0773 - val_recall: 0.7016 - val_auc: 0.6694 - 151ms/epoch - 19ms/step
# Epoch 3/30
# 8/8 - 0s - loss: 1.6674e-04 - fn: 149.0000 - fp: 2431.0000 - precision: 0.0837 - recall: 0.5984 - auc: 0.6862 - val_loss: 0.6148 - val_fn: 51.0000 - val_fp: 716.0000 - val_precision: 0.0925 - val_recall: 0.5887 - val_auc: 0.6873 - 147ms/epoch - 18ms/step
# Epoch 4/30
# 8/8 - 0s - loss: 1.9217e-04 - fn: 148.0000 - fp: 2354.0000 - precision: 0.0865 - recall: 0.6011 - auc: 0.6900 - val_loss: 0.7824 - val_fn: 29.0000 - val_fp: 1256.0000 - val_precision: 0.0703 - val_recall: 0.7661 - val_auc: 0.7069 - 128ms/epoch - 16ms/step
# Epoch 5/30
# 8/8 - 0s - loss: 1.6154e-04 - fn: 94.0000 - fp: 3074.0000 - precision: 0.0827 - recall: 0.7466 - auc: 0.7183 - val_loss: 0.5437 - val_fn: 58.0000 - val_fp: 518.0000 - val_precision: 0.1130 - val_recall: 0.5323 - val_auc: 0.7214 - 125ms/epoch - 16ms/step
# Epoch 6/30
# 8/8 - 0s - loss: 1.5592e-04 - fn: 131.0000 - fp: 2137.0000 - precision: 0.1010 - recall: 0.6469 - auc: 0.7366 - val_loss: 0.6526 - val_fn: 29.0000 - val_fp: 1084.0000 - val_precision: 0.0806 - val_recall: 0.7661 - val_auc: 0.7261 - 113ms/epoch - 14ms/step
# Epoch 7/30
# 8/8 - 0s - loss: 1.5516e-04 - fn: 88.0000 - fp: 2913.0000 - precision: 0.0885 - recall: 0.7628 - auc: 0.7334 - val_loss: 0.5337 - val_fn: 46.0000 - val_fp: 707.0000 - val_precision: 0.0994 - val_recall: 0.6290 - val_auc: 0.7249 - 117ms/epoch - 15ms/step
# Epoch 8/30
# 8/8 - 0s - loss: 1.5070e-04 - fn: 87.0000 - fp: 2678.0000 - precision: 0.0959 - recall: 0.7655 - auc: 0.7515 - val_loss: 0.5988 - val_fn: 30.0000 - val_fp: 882.0000 - val_precision: 0.0963 - val_recall: 0.7581 - val_auc: 0.7477 - 111ms/epoch - 14ms/step
# Epoch 9/30
# 8/8 - 0s - loss: 1.4835e-04 - fn: 93.0000 - fp: 2484.0000 - precision: 0.1007 - recall: 0.7493 - auc: 0.7661 - val_loss: 0.5819 - val_fn: 30.0000 - val_fp: 871.0000 - val_precision: 0.0974 - val_recall: 0.7581 - val_auc: 0.7519 - 111ms/epoch - 14ms/step
# Epoch 10/30
# 8/8 - 0s - loss: 1.4376e-04 - fn: 94.0000 - fp: 2450.0000 - precision: 0.1016 - recall: 0.7466 - auc: 0.7768 - val_loss: 0.6391 - val_fn: 26.0000 - val_fp: 1030.0000 - val_precision: 0.0869 - val_recall: 0.7903 - val_auc: 0.7494 - 107ms/epoch - 13ms/step
# Epoch 11/30
# 8/8 - 0s - loss: 1.4714e-04 - fn: 87.0000 - fp: 2472.0000 - precision: 0.1030 - recall: 0.7655 - auc: 0.7757 - val_loss: 0.5842 - val_fn: 29.0000 - val_fp: 873.0000 - val_precision: 0.0981 - val_recall: 0.7661 - val_auc: 0.7517 - 108ms/epoch - 14ms/step
# Epoch 12/30
# 8/8 - 0s - loss: 1.4327e-04 - fn: 68.0000 - fp: 2679.0000 - precision: 0.1016 - recall: 0.8167 - auc: 0.7815 - val_loss: 0.5238 - val_fn: 39.0000 - val_fp: 704.0000 - val_precision: 0.1077 - val_recall: 0.6855 - val_auc: 0.7487 - 110ms/epoch - 14ms/step
# Epoch 13/30
# 8/8 - 0s - loss: 1.4512e-04 - fn: 68.0000 - fp: 2758.0000 - precision: 0.0990 - recall: 0.8167 - auc: 0.7796 - val_loss: 0.4735 - val_fn: 49.0000 - val_fp: 628.0000 - val_precision: 0.1067 - val_recall: 0.6048 - val_auc: 0.7515 - 104ms/epoch - 13ms/step
# Epoch 14/30
# 8/8 - 0s - loss: 1.4380e-04 - fn: 91.0000 - fp: 2457.0000 - precision: 0.1023 - recall: 0.7547 - auc: 0.7744 - val_loss: 0.5891 - val_fn: 27.0000 - val_fp: 914.0000 - val_precision: 0.0959 - val_recall: 0.7823 - val_auc: 0.7582 - 106ms/epoch - 13ms/step
# Epoch 15/30
# 8/8 - 0s - loss: 1.4162e-04 - fn: 83.0000 - fp: 2587.0000 - precision: 0.1002 - recall: 0.7763 - auc: 0.7797 - val_loss: 0.5492 - val_fn: 38.0000 - val_fp: 886.0000 - val_precision: 0.0885 - val_recall: 0.6935 - val_auc: 0.7464 - 106ms/epoch - 13ms/step
# Epoch 16/30
# 8/8 - 0s - loss: 1.3983e-04 - fn: 78.0000 - fp: 2351.0000 - precision: 0.1108 - recall: 0.7898 - auc: 0.7890 - val_loss: 0.5547 - val_fn: 32.0000 - val_fp: 842.0000 - val_precision: 0.0985 - val_recall: 0.7419 - val_auc: 0.7579 - 105ms/epoch - 13ms/step
# Epoch 17/30
# 8/8 - 0s - loss: 1.3828e-04 - fn: 68.0000 - fp: 2650.0000 - precision: 0.1026 - recall: 0.8167 - auc: 0.7934 - val_loss: 0.5908 - val_fn: 29.0000 - val_fp: 913.0000 - val_precision: 0.0942 - val_recall: 0.7661 - val_auc: 0.7659 - 104ms/epoch - 13ms/step
# Epoch 18/30
# 8/8 - 0s - loss: 1.3727e-04 - fn: 63.0000 - fp: 2487.0000 - precision: 0.1102 - recall: 0.8302 - auc: 0.8003 - val_loss: 0.5285 - val_fn: 34.0000 - val_fp: 824.0000 - val_precision: 0.0985 - val_recall: 0.7258 - val_auc: 0.7596 - 105ms/epoch - 13ms/step
# Epoch 19/30
# 8/8 - 0s - loss: 1.4651e-04 - fn: 79.0000 - fp: 2285.0000 - precision: 0.1133 - recall: 0.7871 - auc: 0.8058 - val_loss: 0.6350 - val_fn: 23.0000 - val_fp: 1020.0000 - val_precision: 0.0901 - val_recall: 0.8145 - val_auc: 0.7667 - 108ms/epoch - 14ms/step
# Epoch 20/30
# 8/8 - 0s - loss: 1.3683e-04 - fn: 73.0000 - fp: 2418.0000 - precision: 0.1097 - recall: 0.8032 - auc: 0.8059 - val_loss: 0.6306 - val_fn: 27.0000 - val_fp: 1008.0000 - val_precision: 0.0878 - val_recall: 0.7823 - val_auc: 0.7674 - 106ms/epoch - 13ms/step
# Epoch 21/30
# 8/8 - 0s - loss: 1.3452e-04 - fn: 68.0000 - fp: 2470.0000 - precision: 0.1093 - recall: 0.8167 - auc: 0.8093 - val_loss: 0.6046 - val_fn: 27.0000 - val_fp: 966.0000 - val_precision: 0.0913 - val_recall: 0.7823 - val_auc: 0.7624 - 102ms/epoch - 13ms/step
# Epoch 22/30
# 8/8 - 0s - loss: 1.3192e-04 - fn: 88.0000 - fp: 2293.0000 - precision: 0.1099 - recall: 0.7628 - auc: 0.8164 - val_loss: 0.5571 - val_fn: 35.0000 - val_fp: 870.0000 - val_precision: 0.0928 - val_recall: 0.7177 - val_auc: 0.7567 - 105ms/epoch - 13ms/step
# Epoch 23/30
# 8/8 - 0s - loss: 1.3387e-04 - fn: 80.0000 - fp: 2315.0000 - precision: 0.1117 - recall: 0.7844 - auc: 0.8072 - val_loss: 0.6630 - val_fn: 24.0000 - val_fp: 1041.0000 - val_precision: 0.0876 - val_recall: 0.8065 - val_auc: 0.7562 - 102ms/epoch - 13ms/step
# Epoch 24/30
# 8/8 - 0s - loss: 1.3506e-04 - fn: 66.0000 - fp: 2455.0000 - precision: 0.1105 - recall: 0.8221 - auc: 0.8010 - val_loss: 0.5046 - val_fn: 40.0000 - val_fp: 747.0000 - val_precision: 0.1011 - val_recall: 0.6774 - val_auc: 0.7538 - 104ms/epoch - 13ms/step
# Epoch 25/30
# 8/8 - 0s - loss: 1.3166e-04 - fn: 60.0000 - fp: 2502.0000 - precision: 0.1106 - recall: 0.8383 - auc: 0.8206 - val_loss: 0.4698 - val_fn: 47.0000 - val_fp: 649.0000 - val_precision: 0.1061 - val_recall: 0.6210 - val_auc: 0.7569 - 111ms/epoch - 14ms/step
# Epoch 26/30
# 8/8 - 0s - loss: 1.2818e-04 - fn: 62.0000 - fp: 2405.0000 - precision: 0.1139 - recall: 0.8329 - auc: 0.8266 - val_loss: 0.5476 - val_fn: 39.0000 - val_fp: 785.0000 - val_precision: 0.0977 - val_recall: 0.6855 - val_auc: 0.7422 - 123ms/epoch - 15ms/step
# Epoch 27/30
# 8/8 - 0s - loss: 1.3203e-04 - fn: 67.0000 - fp: 2323.0000 - precision: 0.1157 - recall: 0.8194 - auc: 0.8180 - val_loss: 0.6226 - val_fn: 28.0000 - val_fp: 968.0000 - val_precision: 0.0902 - val_recall: 0.7742 - val_auc: 0.7562 - 123ms/epoch - 15ms/step
# Epoch 28/30
# 8/8 - 0s - loss: 1.3057e-04 - fn: 75.0000 - fp: 2181.0000 - precision: 0.1195 - recall: 0.7978 - auc: 0.8227 - val_loss: 0.5255 - val_fn: 37.0000 - val_fp: 747.0000 - val_precision: 0.1043 - val_recall: 0.7016 - val_auc: 0.7657 - 126ms/epoch - 16ms/step
# Epoch 29/30
# 8/8 - 0s - loss: 1.2360e-04 - fn: 56.0000 - fp: 2260.0000 - precision: 0.1223 - recall: 0.8491 - auc: 0.8399 - val_loss: 0.5459 - val_fn: 40.0000 - val_fp: 781.0000 - val_precision: 0.0971 - val_recall: 0.6774 - val_auc: 0.7563 - 107ms/epoch - 13ms/step
# Epoch 30/30
# 8/8 - 0s - loss: 1.2675e-04 - fn: 59.0000 - fp: 2322.0000 - precision: 0.1185 - recall: 0.8410 - auc: 0.8312 - val_loss: 0.4447 - val_fn: 44.0000 - val_fp: 609.0000 - val_precision: 0.1161 - val_recall: 0.6452 - val_auc: 0.7608 - 113ms/epoch - 14ms/step

# %%
val_precision
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [88], in <cell line: 1>()
# ----> 1 val_precision
#
# NameError: name 'val_precision' is not defined

# %%
from keras.callbacks import TensorBoard
from tensorboard.plugins.pr_curve import summary as pr_summary

# Check complete example in:
# https://github.com/akionakamura/pr-tensorboard-keras-example
class PRTensorBoard(TensorBoard):
    def __init__(self, *args, **kwargs):
        # One extra argument to indicate whether or not to use the PR curve summary.
        self.pr_curve = kwargs.pop('pr_curve', True)
        super(PRTensorBoard, self).__init__(*args, **kwargs)

        global tf
        import tensorflow as tf

    def set_model(self, model):
        super(PRTensorBoard, self).set_model(model)

        if self.pr_curve:
            # Get the prediction and label tensor placeholders.
            predictions = self.model._feed_outputs[0]
            labels = tf.cast(self.model._feed_targets[0], tf.bool)
            # Create the PR summary OP.
            self.pr_summary = pr_summary.op(tag='pr_curve',
                                            predictions=predictions,
                                            labels=labels,
                                            display_name='Precision-Recall Curve')

    def on_epoch_end(self, epoch, logs=None):
        super(PRTensorBoard, self).on_epoch_end(epoch, logs)

        if self.pr_curve and self.validation_data:
            # Get the tensors again.
            tensors = self.model._feed_targets + self.model._feed_outputs
            # Predict the output.
            predictions = self.model.predict(self.validation_data[:-2])
            # Build the dictionary mapping the tensor to the data.
            val_data = [self.validation_data[-2], predictions]
            feed_dict = dict(zip(tensors, val_data))
            # Run and add summary.
            result = self.sess.run([self.pr_summary], feed_dict=feed_dict)
            self.writer.add_summary(result[0], epoch)
        self.writer.flush()
